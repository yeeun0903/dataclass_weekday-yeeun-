# %% [markdown]
# ### 데이터 과정 Flow
#
# 1. 파이썬 기초문법
# 2. 크롤링 (requests, bs4) 기초문법
# 3. 크롤링 데이터 저장방법 (xlsx)
# 4. API를 활용한 데이터 수집방법

# %%
# API = Application Programming Interface
# Application를 Programming하는데 있어서, 처음부터 개발하지 않고, 기존 서비스의 측면에 접속에서 데이터를 가져온 후 그 데이터를 기반으로 Programming을 하겠다. 
# 네이버 > 오늘의 날씨 안내 정보 > 네이버 기상청 x
# 버정, 지하철 > 시? 자리? > 카카오맵 서비스
# 정부기관 제공 버스, 지하철 공공교통 정보 수집 > 카카오
# 어떤 서비스를 만든다는 이야기 = CRUD
# Create
# Read
# Update
# Delete

# %%
# Naver API
# 공공데이터포털 API
# 카카오 API
# TMDB API
# OpenweatherMap API

# %%
# 지금까지 배운 방법 : Naver 크롤링 불가
# http://127.0.0.1:5500/ -> http://localhost
# http://194.289.098:5300/ -> naver
# 네이버 개발자센터 > API 신청 > 주소값
# 포스트맨 > API 값 활용 > 데이터 수집
# TMDB > 개별적으로 회원가입

# %%
import json

data = """
{
    "lastBuildDate": "Fri, 23 Jan 2026 14:32:52 +0900",
    "total": 180211,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "서울역 한정선 찹쌀떡 두바이 딸기 <b>두쫀쿠</b> 보관방법 위치 포장",
            "link": "https://blog.naver.com/starkimpt/224152385379",
            "description": "요즘 <b>두쫀쿠</b> 열풍이 대단합니다 한양 나들이 갔다가 서울역 내에 위치한 한정선 찹쌀떡 방문했어요... 서울역 <b>두쫀쿠</b> 웨이팅 있지는 않았어요. 다음날 일요일 오후에는 줄이 더 길기는 했지만 빠르게... ",
            "bloggername": "유니크한 나의 하루",
            "bloggerlink": "blog.naver.com/starkimpt",
            "postdate": "20260119"
        },
        {
            "title": "<b>두쫀쿠</b> 만들기! 자도르님 레시피로 만든 요즘 대란 디저트",
            "link": "https://blog.naver.com/ssmmku/224149788058",
            "description": "없는 <b>두쫀쿠</b>인데 요즘 여기저기서 너무 많이 보이길래 대체 어떤 맛이길래 이렇게 대란인가... 만들어본 <b>두쫀쿠</b>치고는 비주얼도 만족❤ 반으로 잘라보니 겉 마시멜로 쉘이 생각보다 탄탄해서 모양이... ",
            "bloggername": "우리의 일상 ❤️",
            "bloggerlink": "blog.naver.com/ssmmku",
            "postdate": "20260117"
        },
        {
            "title": "<b>두쫀쿠</b> 피스타치오 스프레드 만들기 페이스트 레시피",
            "link": "https://blog.naver.com/naettee/224154201325",
            "description": "피스타치오 스프레드 만들기 제가 <b>두쫀쿠</b> 레시피를 올린게 한 달이 넘었는데요. 그때까지만 해도... 완성 이대로 구운 카다이프에 화이트초콜릿이랑 같이 넣고 섞어서 <b>두쫀쿠</b> 속으로 활용하면 됩니다.... ",
            "bloggername": "네뜨,베리의 달달한 하루",
            "bloggerlink": "blog.naver.com/naettee",
            "postdate": "20260121"
        },
        {
            "title": "강남 <b>두쫀쿠</b> 파는곳 두바이 쫀득쿠키 쿄베이커리",
            "link": "https://blog.naver.com/psy9133/224148125425",
            "description": "강남 <b>두쫀쿠</b> 파는곳 두바이쫀득쿠키 쿄(KYO) 베이커리 글. 사진 ⓒ은솔희섭mom 오늘 지인들 모임이... 앞에 줄서있는 분들에게 무슨줄이냐고 물어보니 <b>두쫀쿠</b> 줄이랍니다. 와우! 12시에 판매시작한다는데 우리는... ",
            "bloggername": "은솔희섭mom의 데이바이데이 story~*",
            "bloggerlink": "blog.naver.com/psy9133",
            "postdate": "20260115"
        },
        {
            "title": "편의점<b>두쫀쿠</b> 몬트쿠키 원조 <b>두쫀쿠</b>보다 맛있었던 gs 두바이... ",
            "link": "https://blog.naver.com/ph_theflower/224148717460",
            "description": "편의점<b>두쫀쿠</b> 원조보다 맛있었던 gs 두바이 쫀득 초코볼 글/사진/영상 ⓒ슈어킴 얼마 전, <b>두쫀쿠</b>의 원조라는 몬트쿠키 <b>두쫀쿠</b>를 처음 맛봤어요. 기대가 컸던 탓일까요? 한 입 먹고 나서 든 생각은 &quot;이런 게... ",
            "bloggername": "뚜벅뚜벅 육아여행",
            "bloggerlink": "blog.naver.com/ph_theflower",
            "postdate": "20260116"
        },
        {
            "title": "<b>두쫀쿠</b> 재료 피스타치오 스프레드 페이스트 만들기 200g 껍질... ",
            "link": "https://blog.naver.com/egg6772/224156383136",
            "description": "덕분에 <b>두쫀쿠</b> 만들기 재료를 구입하는 것조차 어렵게 되어 버렸어요 스프레드 또한 품절인 경우가... 작동한답니다 <b>두쫀쿠</b> 만들기 재료 껍질 피스타치오 200g 피스타치오 스프레드 만드는 법 피스타치오 굽는... ",
            "bloggername": "구월동 윤스키친",
            "bloggerlink": "blog.naver.com/egg6772",
            "postdate": "20260123"
        },
        {
            "title": "인계동 <b>두쫀쿠</b> 맛집 카페디아즈 수원시청역 디저트 후기",
            "link": "https://blog.naver.com/kk0jjin/224154733457",
            "description": "인계동 <b>두쫀쿠</b> 맛집 카페디아즈 인계본점 테이크아웃 찐후기! 직접 구운 피스타치오 두바이 쫀득쿠키... 오늘은 인계동에서 '<b>두쫀쿠</b>(두바이 쫀득 쿠키)'로 가장 핫하다는 카페디아즈 인계본점 테이크아웃... ",
            "bloggername": "❤️꼬꼬찐이❤️",
            "bloggerlink": "blog.naver.com/kk0jjin",
            "postdate": "20260121"
        },
        {
            "title": "<b>두쫀쿠</b> 피스타치오 스프레드 만들기 페이스트 레시피 꿀팁",
            "link": "https://blog.naver.com/junmega/224156257100",
            "description": "<b>두쫀쿠</b> 피스타치오 스프레드 만들기 페이스트 레시피 꿀팁 글.사진@은하계쓰 요즘 SNS에서 핫한 디저트를 꼽으라면 단연 두바이 쫀득 쿠키(<b>두쫀쿠</b>)가 아닐까 싶어요. 저도 겨울방학을 맞이한 아이들과 함께... ",
            "bloggername": "은하계쓰의 지구별여행",
            "bloggerlink": "blog.naver.com/junmega",
            "postdate": "20260122"
        },
        {
            "title": "파리바게트 <b>두쫀쿠</b> 파바 두쫀볼 파는곳 두바이 쫀득볼 판매 시간",
            "link": "https://blog.naver.com/alswl0224/224149010845",
            "description": "파리바게트 <b>두쫀쿠</b> 파바 두쫀볼 파는곳 두바이 쫀득볼 판매 시간 요즘 두바이 열풍이 핫하잖아요... <b>두쫀쿠</b> 품절대란나서 사먹고 싶어도 매번 실패했는데 파바에서라도 사먹어야겠다~ 라고 생각했거든요.... ",
            "bloggername": "망디의먹로그",
            "bloggerlink": "blog.naver.com/alswl0224",
            "postdate": "20260116"
        },
        {
            "title": "성수동 핫플 두바이 쫀득쿠키 파는곳 | <b>두쫀쿠</b> 성수 팝업스토어... ",
            "link": "https://blog.naver.com/kongmistar/224155827429",
            "description": "파는곳 <b>두쫀쿠</b> 성수 팝업스토어 방문 후기 사진, 글: 콩미 여행과 일상의 소중한 순간을 기록하는 인플루언서 콩미입니다 오늘은 요즘 SNS를 가장 뜨겁게 달구고 있는 화제의 디저트 두바이 쫀득쿠키(<b>두쫀쿠</b>)... ",
            "bloggername": "행복한 여행 동반자 콩미",
            "bloggerlink": "blog.naver.com/kongmistar",
            "postdate": "20260122"
        }
    ]
}
"""

json_data = json.loads(data)
# print(json_data["items"])

for item in json_data["items"] :
    print(item["title"])
# Out:
# 서울역 한정선 찹쌀떡 두바이 딸기 <b>두쫀쿠</b> 보관방법 위치 포장
# <b>두쫀쿠</b> 만들기! 자도르님 레시피로 만든 요즘 대란 디저트
# <b>두쫀쿠</b> 피스타치오 스프레드 만들기 페이스트 레시피
# 강남 <b>두쫀쿠</b> 파는곳 두바이 쫀득쿠키 쿄베이커리
# 편의점<b>두쫀쿠</b> 몬트쿠키 원조 <b>두쫀쿠</b>보다 맛있었던 gs 두바이...
# <b>두쫀쿠</b> 재료 피스타치오 스프레드 페이스트 만들기 200g 껍질...
# 인계동 <b>두쫀쿠</b> 맛집 카페디아즈 수원시청역 디저트 후기
# <b>두쫀쿠</b> 피스타치오 스프레드 만들기 페이스트 레시피 꿀팁
# 파리바게트 <b>두쫀쿠</b> 파바 두쫀볼 파는곳 두바이 쫀득볼 판매 시간
# 성수동 핫플 두바이 쫀득쿠키 파는곳 | <b>두쫀쿠</b> 성수 팝업스토어...

# %% [markdown]
# ### JSON
# - Javascript Object Notation = 자바스크립트 객체 표기법
# - 웹사이트 js (*oop = 객체지향) : 프론트엔드 진영의 프로그래밍 대표 언어
# - 객체지향 언어 -> 최대한 보존 -> 프론트 & 백엔드 소통 -> JSON
# - 백엔드 진영의 프로그래밍 대표 언어 : Java (*oop = 객체지향)
# - { "name": "David" }
#
# ### XML
# - Extensible Markup Language

# %%
import requests

client_id = "eJLO1xl63hNfH5lFsOgZ"
client_secret = "zsu_DFMJN1"

naver_open_api = "https://openapi.naver.com/v1/search/shop.json?query=독도토너"
header_params = {
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret
}

res = requests.get(naver_open_api, headers=header_params)

if res.status_code == 200 :
    data = res.json()
    for index, item in enumerate(data["items"]) :
        print(index + 1, item["title"], item["link"])
else :
    print("Error Code :", res.status_code)
# Out:
# 1 라운드랩 1025 <b>독도 토너</b> 500ml, 1개 https://search.shopping.naver.com/catalog/51929211751
# 2 라운드랩 <b>독도 토너</b> 500ml + 100ml 무자극 영양 미네랄 워터 함유 https://smartstore.naver.com/main/products/12277061304
# 3 라운드랩 1025 <b>독도 토너</b> 500ml+100ml 대용량 기획 스킨 https://www.11st.co.kr/connect/Gateway.tmall?method=Xsite&prdNo=8547812911&tid=1000000061
# 4 라운드랩 1025 <b>독도토너</b>/로션 2종[저자극/세트] https://smartstore.naver.com/main/products/11411850378
# 5 라운드랩 1025 독도 로션 400ml + <b>독도 토너</b> 500ml+100ml 대용량 https://www.11st.co.kr/connect/Gateway.tmall?method=Xsite&prdNo=8547824954&tid=1000000061
# 6 라운드랩 1025 독도로션 400ml +<b>독도토너</b> 500ml 피부보습 각질케어 올영 https://smartstore.naver.com/main/products/9653286803
# 7 라운드랩 라운드랩 1025 <b>독도 토너</b> 대용량 500ml+100ml https://link.auction.co.kr/gate/pcs?item-no=F275438299&sub-id=1&service-code=10000003
# 8 닥터지 레드 블레미쉬 클리어 수딩 <b>토너</b> 500ml, 1개 https://search.shopping.naver.com/catalog/51929470275
# ...

# %%
import requests
import openpyxl

client_id = "eJLO1xl63hNfH5lFsOgZ"
client_secret = "zsu_DFMJN1"

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["B"].width = 100
excel_sheet.column_dimensions["C"].width = 100
excel_sheet.append(["No", "제목", "링크"])
# A열 : 1~1000, B열 : 제목, C열 : 상품링크
# 행 : 1행 : No 제목 상품링크

# 기본 10개, 100개 : 1 ~ 100 // 101 ~ 200 / 201 ~ 300 ... 901 ~ 1000
# start = 1 ~ 100 // 101

start = 1
num = 0

for index in range(10) :
    start_number = start + (index * 100)

    naver_open_api = f"https://openapi.naver.com/v1/search/shop.json?query=독도토너&display=100&start={str(start_number)}"
    header_params = {
        "X-Naver-Client-Id": client_id,
        "X-Naver-Client-Secret": client_secret
    }
    
    res = requests.get(naver_open_api, headers=header_params)
    
    if res.status_code == 200 :
        data = res.json()
        for item in data["items"] :
            num += 1
            excel_sheet.append([num, item["title"], item["link"]])
    else :
        print("Error Code :", res.status_code)
        
excel_file.save("shopping_with_독도토너.xlsx")
excel_file.close()

print("✅shopping_with_독도토너.xlsx 파일 저장 완료!")
# Out:
# ✅shopping_with_독도토너.xlsx 파일 저장 완료!
