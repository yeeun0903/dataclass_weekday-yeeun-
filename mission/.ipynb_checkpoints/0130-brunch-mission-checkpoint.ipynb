# %% [markdown]
# 1. 브런치 사이트접속
# 2. RECOMMENDED ARTICLES 제목 선택자, 아이디, 클래스 확인
# 3. 확인 후 데이터를 찾아서 출력한다

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time 


service = Service(ChromeDriverManager().install())
URL = "https://brunch.co.kr/"

options = Options()
# options.add_argument("--headless") 
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage") 
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR") 
options.add_argument("--no-sandbox") 


driver = webdriver.Chrome(service=service, options=options)  
driver.get(URL)
time.sleep(2)

driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
time.sleep(2)

elements = driver.find_elements(By.CSS_SELECTOR, "ul.list_slide.embla__container.svelte-117s9qv > li.embla__slide.svelte-117s9qv strong.tit_subject")
for element in elements:
    print(element.text) 
 

driver.quit()
# Out:
# 카페를 연 지 5개월 만에 폐업합니다
# 보일러 계속 켜고도 난방비 10만 원 줄였습니다
# 퇴사하고 나서야 알게 된 것들
# 정리가 어려운 당신에게
# 강제적 퇴직, 당혹감과 망막함
# 내 생에 첫 수영장 회식
