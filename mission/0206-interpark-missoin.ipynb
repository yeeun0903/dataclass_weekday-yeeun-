# %%
# 인터파크 > 티켓 > 뮤지컬 > 뮤지컬 둘러보기 > 공연이름 공연장 기간 > 20개!!

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time

URL = "https://nol.interpark.com/" 
service = Service(ChromeDriverManager().install())
options = Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
# options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-sandbox")
                     
driver = webdriver.Chrome(service=service, options=options)                     
driver.get(URL) 
time.sleep(2)

ticket = "https://nol.interpark.com/ticket"
driver.get (ticket)
time. sleep(2)

musical = "https://tickets.interpark.com/contents/genre/musical"
driver.get(musical)
time.sleep(2)

btn = driver.find_element(By.XPATH, "//*[@class='ScrollPanel_scroll__8af96'][1]//div//button[2]").click()
time.sleep(5)

driver.execute_script("window.scrollTo(0, 3000);") 
time.sleep(2)

items = driver.find_elements(By.CSS_SELECTOR, "div.ProductList_contents__eUxgq a")[:20]
for idx, item in enumerate (items) :
    name = item.find_element(By.CSS_SELECTOR, "li.TicketItem_goodsName__Ju76j").text.strip()
    place = item.find_element(By.CSS_SELECTOR, "li.TicketItem_placeName__ls_9C").text.strip()
    date = item.find_element(By.CSS_SELECTOR, "li.TicketItem_playDate__5ePr2").text.strip()
    print(f"{idx+1} {name} / {place} / {date}")
driver.quit()
# Out:
# 1 판 / 동덕여자대학교 공연예술센터 코튼홀 / 2025.12.23 - 2026.03.08
# 2 트레이스 유 / 링크아트센터 벅스홀 / 2025.12.04 - 2026.03.01
# 3 ROGER / NOL 서경스퀘어 스콘 2관 / 2026.03.05 - 2026.05.31
# 4 위키드(WICKED The Musical) - 대구 / 계명아트센터 / 2026.02.05 - 2026.03.01
# 5 A여고 사서의 영광과 비극 / 링크아트센터드림 드림2관 / 2026.01.27 - 2026.04.26
# 6 이터니티 / NOL 유니플렉스 1관 / 2025.12.27 - 2026.03.15
# 7 제임스 바이런 딘 / 극장 온 / 2026.01.09 - 2026.03.01
# 8 전설의 리틀 농구단 / 플러스씨어터 / 2026.03.10 - 2026.05.25
# 9 너를 위한 글자 / 링크아트센터드림 드림4관 / 2026.03.04 - 2026.05.31
# 10 디아길레프 / 예스24아트원 1관 / 2026.03.31 - 2026.06.14
# 11 로미오와 줄리엣 / 한전아트센터 / 2026.03.24 - 2026.05.31
# 12 태권, 날아올라 / 국립중앙박물관 극장 용 / 2026.04.04 - 2026.05.31
# 13 로빈 / 대학로 TOM(티오엠) 1관 / 2025.12.01 - 2026.03.01
# 14 존 도우 / NOL 서경스퀘어 스콘 1관 / 2025.12.10 - 2026.03.01
# 15 시지프스 / 예스24스테이지 2관 / 2025.12.16 - 2026.03.08
# 16 타오르는 어둠 속에서 / 링크아트센터 페이코홀 / 2025.12.10 - 2026.03.08
# 17 난쟁이들 / 플러스씨어터 / 2025.11.05 - 2026.03.01
# 18 말리 / 백암아트홀 / 2025.12.20 - 2026.02.15
# ...
