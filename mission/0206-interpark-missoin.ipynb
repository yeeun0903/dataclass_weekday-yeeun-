# %%
# 인터파크 > 티켓 > 뮤지컬 > 뮤지컬 둘러보기 > 공연이름 공연장 기간 > 20개!!

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time

URL = "https://nol.interpark.com/" 
service = Service(ChromeDriverManager().install())
options = Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR") 
options.add_argument("--no-sandbox") 

driver = webdriver.Chrome(service=service, options=options)
driver.get(URL)
time.sleep(2)

ticket = "https://nol.interpark.com/ticket"
driver.get(ticket)
time.sleep(2)

musical = "https://tickets.interpark.com/contents/genre/musical"
driver.get(musical)
time.sleep(2)

elements = driver.find_elements(By.CSS_SELECTOR, "div.ProductList_contents__eUxgq")

for index, item in enumerate(elements[:20]):
    name = elements.find_elements(By.CSS_SELECTOR, li.TicketItem_goodsName__Ju76j)
    place = elements.find_elements(By.CSS_SELECTOR, li.TicketItem_placeName__ls_9C)
    date = elements.find_elements(By.CSS_SELECTOR, li.TicketItem_playDate__5ePr2)
    print(index + 1, name.text, place.text, date.text)
    
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 37
#      34 elements = driver.find_elements(By.CSS_SELECTOR, "div.ProductList_contents__eUxgq")
#      36 for index, item in enumerate(elements[:20]):
# ---> 37     name = elements.find_elements(By.CSS_SELECTOR, li.TicketItem_goodsName__Ju76j)
#      38     place = elements.find_elements(By.CSS_SELECTOR, li.TicketItem_placeName__ls_9C)
#      39     date = elements.find_elements(By.CSS_SELECTOR, li.TicketItem_playDate__5ePr2)
#
# AttributeError: 'list' object has no attribute 'find_elements'

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time

URL = "https://nol.interpark.com/" 
service = Service(ChromeDriverManager().install())
options = Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR") 
options.add_argument("--no-sandbox") 

driver = webdriver.Chrome(service=service, options=options)
driver.get(URL)
time.sleep(2)

ticket = "https://nol.interpark.com/ticket"
driver.get(ticket)
time.sleep(2)

musical = "https://tickets.interpark.com/contents/genre/musical"
driver.get(musical)
time.sleep(2)

elements = driver.find_elements(By.CSS_SELECTOR, "div.ProductList_contents__eUxgq")
for item in enumerate(elements[:20]):
    name = elements.find_elements(By.CSS_SELECTOR, ".TicketItem_goodsName__Ju76j")
    print(name.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 36
#      34 elements = driver.find_elements(By.CSS_SELECTOR, "div.ProductList_contents__eUxgq")
#      35 for item in enumerate(elements[:20]):
# ---> 36     name = elements.find_elements(By.CSS_SELECTOR, ".TicketItem_goodsName__Ju76j")
#      37     print(name.text)
#
# AttributeError: 'list' object has no attribute 'find_elements'
