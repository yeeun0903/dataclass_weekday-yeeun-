# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time

URL = "https://www.ssg.com/" 
service = Service(ChromeDriverManager().install())
options = Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
# options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-sandbox")

# SSG 사이트 접속하기
driver = webdriver.Chrome(service=service, options=options)                     
driver.get(URL) 
time.sleep(2)

# 신세계몰 버튼 클릭 
new_btn = driver.find_element(By.XPATH, "//*[@class='gnb_mall_list']/li[2]/a").click()
time.sleep(2)

# 쓱특가 버튼 클릭 
ssg_btn = driver.find_element(By.XPATH, "//*[@class='smgnb_navbar']/div[2]/ul/li[1]/a").click()
time.sleep(2)

# 리빙 버튼 클릭
living_btn = driver.find_element(By.ID, "tabs-:Rcledaal6nj6:--tab-7").click()
time.sleep(2)

# 스크롤 내리기
driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
time.sleep(2)

# 상품명，할인，가격，주소 -> class 속성값 
items = driver.find_elements(By.CSS_SELECTOR, "div.template-grid-item.css-8kawlz")
for idx, item in enumerate(items) :
    try:
        name = item.find_element(By.XPATH, ".//p").text.replace("\n", " ").strip()
        sale = item.find_element(By.XPATH, ".//em[1]").text.replace("\n", " ").strip()
        price = item.find_element(By.XPATH, ".//em[2]").text.replace("\n", " ").strip()
        url = item.find_element(By.XPATH, ".//a[@href]").get_attribute("href")
    except:
        continue
    print(f"{idx+1} {name}\n {sale}, {price}\n {url}\n")
driver.quit()
# Out:
# 1 엘지생활건강LG 설 선물세트 ~30% S머니 최대 50만원 적립
#  할인율 ~30%, 판매가격 22,344원외
#  https://shinsegaemall.ssg.com/item/dealItemView.ssg?itemId=1000291434400&siteNo=6004&salestrNo=6005
#
# 2 H&M감각적인 침실 침구, 홈상품 단독가로
#  할인율 ~31%, 판매가격 17,010원외
#  https://shinsegaemall.ssg.com/item/dealItemView.ssg?itemId=1000049584132&siteNo=6004&salestrNo=6005
#
# 3 까사미아헤리티지 식기류 최저가 20%+S머니+카드할인
#  할인율 ~10%, 판매가격 16,200원외
#  https://shinsegaemall.ssg.com/item/dealItemView.ssg?itemId=1000791000944&siteNo=6004&salestrNo=6005
#
# 4 시몬스1등브랜드의 침대/매트리스 ~33% 할인
#  할인율 ~33%, 판매가격 1,363,250원외
#  https://shinsegaemall.ssg.com/item/dealItemView.ssg?itemId=1000050842275&siteNo=6004&salestrNo=6005
#
# 5 에이스침대숙면을 선물하는 침대과학 ~19% 시크릿할인
#  할인율 ~19%, 판매가격 398,520원외
#  https://shinsegaemall.ssg.com/item/dealItemView.ssg?itemId=1000591302145&siteNo=6004&salestrNo=6005
#
# 6 드롱기베스트템 세일 기프트 추천
#  할인율 ~22%, 판매가격 107,100원외
#  https://shinsegaemall.ssg.com/item/dealItemView.ssg?itemId=1000598830928&siteNo=6009&salestrNo=1002
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time

URL = "https://www.ssg.com/" 
service = Service(ChromeDriverManager().install())
options = Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
# options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-sandbox")

# SSG 사이트 접속하기
driver = webdriver.Chrome(service=service, options=options)                     
driver.get(URL) 
time.sleep(2)

# 신세계몰 버튼 클릭 
new_btn = driver.find_element(By.XPATH, "//*[@class='gnb_mall_list']/li[2]/a").click()
time.sleep(2)

# 쓱특가 버튼 클릭 
ssg_btn = driver.find_element(By.XPATH, "//*[@class='smgnb_navbar']/div[2]/ul/li[1]/a").click()
time.sleep(2)

# 식품 버튼 클릭
food_btn = driver.find_element(By.ID, "tabs-:Rcledaal6nj6:--tab-8").click()
time.sleep(2)

# 스크롤 내리기
driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
time.sleep(2)

# 상품명，할인，가격，주소 -> 다른 건 다 있는데!!! 할인률이 없는 상품들이 섞여있음 -> try 구문 써야징
items = driver.find_elements(By.CSS_SELECTOR, "div.template-grid-item.css-8kawlz")[:50]
for idx, item in enumerate(items):
    # 상품명
    try:
        name = item.find_element(By.XPATH, ".//p").text.replace("\n", " ").strip()
    except:
        name = ""
    # 할인률
    try:
        sale = item.find_element(By.XPATH, ".//em[1]").text.replace("\n", " ").strip()
    except:
        sale = ""
    #가격
    try:
        price = item.find_element(By.XPATH, ".//em[2]").text.replace("\n", " ").strip()
    except:
        price = ""
    # 주소
    try:
        url = item.find_element(By.XPATH, ".//a[@href]").get_attribute("href")
    except:
        url = ""
    print(f"{idx+1} {name}\n {sale}, {price} {url}")
driver.quit()
# Out:
# 1 정관장NO.1 홍삼으로 새해준비 전상품 10% 할인
#  할인율 ~10%, 판매가격 198,000원외 https://shinsegaemall.ssg.com/item/dealItemView.ssg?itemId=1000682002385&siteNo=6009&salestrNo=1002
# 2 SSG정담상주감도가 곶감세트 명절 전 배송
#  할인율 21%, 판매가격 72,900원 https://shinsegaemall.ssg.com/item/itemView.ssg?itemId=1000029101395&siteNo=6004&salestrNo=6005
# 3 CJ제일제당비비고 국물세트 57%할인행사
#  할인율 57%, 판매가격 18,500원 https://shinsegaemall.ssg.com/item/itemView.ssg?itemId=1000790939484&siteNo=6004&salestrNo=6005
# 4 한상궁김치 멤버십특가 45%할인행사
#  할인율 45%, 판매가격 11,400원 https://shinsegaemall.ssg.com/item/itemView.ssg?itemId=1000781804415&siteNo=6004&salestrNo=6005
# 5 스위트라운지말차와 망고의 만남 예맛 신상품 특별할인
#  할인율 10%, 판매가격 53,100원 https://shinsegaemall.ssg.com/item/itemView.ssg?itemId=1000791415165&siteNo=6009&salestrNo=1013
# 6 SSG정담영광법성포 굴비세트 13일 12시까지 주문 가능
#  할인율 ~11%, 판매가격 68,030원외 https://shinsegaemall.ssg.com/item/dealItemView.ssg?itemId=1000020639145&siteNo=6004&salestrNo=6005
# 7 인제축협인제축협 설날 한우선물세트 ~42% 인기상품 할인
# ...
